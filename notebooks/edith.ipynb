# %% [markdown]
# # Edith — Tyrwar Operational Notebook
#
# Edith is a thin operator interface for the canonical Tyrwar runtime. It does not contain strategy, execution, risk, telemetry, or MT5 logic. Those responsibilities remain under `src/tyrwar/`.
#
# ## Safety
#
# - Evaluation mode is the default.
# - Live execution requires the runtime's explicit command and environment safeguards.
# - Configure telemetry through environment variables; do not place secrets in this notebook.

# %%
from tyrwar.cli import run_tyrwar

# %% [markdown]
# ## One-cycle evaluation
#
# Use this cell to verify MT5 connectivity, strategy evaluation, and telemetry without starting a continuous loop.

# %%
run_tyrwar(
    symbol="XAUUSDm",
    continuous=False,
    poll_seconds=15.0,
    execute=False,
)

# %% [markdown]
# ## Continuous evaluation
#
# Run this cell only after the one-cycle evaluation succeeds. Stop it with the notebook interrupt control.

# %%
run_tyrwar(
    symbol="XAUUSDm",
    continuous=True,
    poll_seconds=15.0,
    execute=False,
)
